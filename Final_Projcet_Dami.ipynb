# %% [markdown]
# Business understanding bertujuan untuk menjawab permasalahan bisnis mengenai tugas analitis yang perlu diselesaikan. Permasalahan yang dibahas adalah regresi atau memprediksi nilai kontinu dari kasus prediksi biaya pada BPJS. Ini bertujuan untuk mengembangkan sebuah model data mining
# Pada meta data yang kami  pilih yaitu case 3 terdapat beberapa fitur sebagai berikut :
#
# Kode Provinsi :
# Nama Provinsi	:
# kode_kabupaten/kota	nama_kabupaten/kota :

# %% [markdown]
# ##Business Understanding

# %%
#import drive agar data pada drive dapat digunakan
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Mengimport library atau module yang diperlukan
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.offline import iplot
import warnings

warnings.filterwarnings('ignore')

# %%
import pandas as pd

# Menggunakan double quotes untuk string literal dan menambahkan tanda kutip tunggal di akhir
df = pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/2022 Metadata Data Sampel BPJS Kesehatan.csv', sep=";")
df
# Out:
#      kode_prov               nama_provinsi  kode_kabupaten/kota  \
# 0         11.0                        ACEH               1101.0
# 1          NaN                         NaN               1102.0
# 2          NaN                         NaN               1103.0
# 3          NaN                         NaN               1104.0
# 4          NaN                         NaN               1105.0
# 5          NaN                         NaN               1106.0
# 6          NaN                         NaN               1107.0
# 7          NaN                         NaN               1108.0
# 8          NaN                         NaN               1109.0
# 9          NaN                         NaN               1110.0
# 10         NaN                         NaN               1111.0
# 11         NaN                         NaN               1112.0
# 12         NaN                         NaN               1113.0
# 13         NaN                         NaN               1114.0
# ...

# %%
#melihat informasi yang terdapat pada dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   kode_prov            35 non-null     float64
#  1   nama_provinsi        35 non-null     object
#  2   kode_kabupaten/kota  515 non-null    float64
#  3   nama_kabupaten/kota  515 non-null    object
#  4   Unnamed: 4           0 non-null      float64
#  5   Unnamed: 5           0 non-null      float64
#  6   Unnamed: 6           0 non-null      float64
# dtypes: float64(5), object(2)
# memory usage: 28.3+ KB

# %%
df = df[['kode_prov', 'nama_provinsi', 'kode_kabupaten/kota', 'nama_kabupaten/kota']]
df.head()
# Out:
#    kode_prov nama_provinsi  kode_kabupaten/kota nama_kabupaten/kota
# 0       11.0          ACEH               1101.0            SIMEULUE
# 1        NaN           NaN               1102.0        ACEH SINGKIL
# 2        NaN           NaN               1103.0        ACEH SELATAN
# 3        NaN           NaN               1104.0       ACEH TENGGARA
# 4        NaN           NaN               1105.0          ACEH TIMUR

# %%
df['kode_prov'].loc[1:22] = df['kode_prov'].loc[1:22].fillna(11)
df
# Out:
#      kode_prov               nama_provinsi  kode_kabupaten/kota  \
# 0         11.0                        ACEH               1101.0
# 1         11.0                         NaN               1102.0
# 2         11.0                         NaN               1103.0
# 3         11.0                         NaN               1104.0
# 4         11.0                         NaN               1105.0
# 5         11.0                         NaN               1106.0
# 6         11.0                         NaN               1107.0
# 7         11.0                         NaN               1108.0
# 8         11.0                         NaN               1109.0
# 9         11.0                         NaN               1110.0
# 10        11.0                         NaN               1111.0
# 11        11.0                         NaN               1112.0
# 12        11.0                         NaN               1113.0
# 13        11.0                         NaN               1114.0
# ...

# %%
df.describe()
# Out:
#        kode_prov  kode_kabupaten/kota
# count  57.000000           515.000000
# mean   34.350877          4584.790291
# std    28.436327          2688.951769
# min    11.000000          1101.000000
# 25%    11.000000          1804.500000
# 50%    17.000000          3572.000000
# 75%    62.000000          7201.500000
# max    99.000000          9999.000000

# %%
#cek duplikat
df.duplicated().sum()
# Out:
# 0

# %%
#cek missing value
df.isnull().sum()
# Out:
# kode_prov              459
# nama_provinsi          481
# kode_kabupaten/kota      1
# nama_kabupaten/kota      1
# dtype: int64
